# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt("lcurve.out", names=True)
columns = [3,5]
for column in columns:
    name = data.dtype.names[column]
    plt.plot(data['step'], data[name], label=name)
# for name in data.dtype.names[1:3]:
#     plt.plot(data['step'], data[name], label=name)
plt.legend(loc="lower center", frameon=False )
plt.xlabel('Step')
plt.ylabel('Loss')
plt.xscale('symlog')
plt.yscale('log')
#plt.grid()
plt.yticks()
#yticks([])
plt.show()

# %%
data[name]
# Out:
# array([ 0.0238,  0.0253,  0.0309, ...,  0.0184,  0.0203,  0.0169])
